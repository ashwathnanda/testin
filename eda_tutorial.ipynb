# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('churn.csv')

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...    total eve calls  total eve charge  \
# ...

# %% [markdown]
# Statictical Descirption of the dataset

# %%
df.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# Information on the type and count of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
# state                     3333 non-null object
# account length            3333 non-null int64
# area code                 3333 non-null int64
# phone number              3333 non-null object
# international plan        3333 non-null object
# voice mail plan           3333 non-null object
# number vmail messages     3333 non-null int64
# total day minutes         3333 non-null float64
# total day calls           3333 non-null int64
# total day charge          3333 non-null float64
# total eve minutes         3333 non-null float64
# total eve calls           3333 non-null int64
# total eve charge          3333 non-null float64
# total night minutes       3333 non-null float64
# total night calls         3333 non-null int64
# total night charge        3333 non-null float64
# total intl minutes        3333 non-null float64
# total intl calls          3333 non-null int64
# ...

# %% [markdown]
# Changing the datatype of any column

# %%
df['churn'] = df['churn'].astype('int64')

# %% [markdown]
# Describing columns with non-numerical value

# %%
df.describe(include = ['object','bool'])
# Out:
#        state phone number international plan voice mail plan
# count   3333         3333               3333            3333
# unique    51         3333                  2               2
# top       WV     374-1684                 no              no
# freq     106            1               3010            2411

# %% [markdown]
# Normalized count of the output variable

# %%
df['churn'].value_counts(normalize = True)
# Out:
# 0    0.855086
# 1    0.144914
# Name: churn, dtype: float64

# %% [markdown]
# Sorting dataset wrt single column

# %%
df.sort_values(by = 'total day minutes')
# Out:
#      state  account length  area code phone number international plan  \
# 1345    SD              98        415     392-2555                 no
# 1397    VT             101        510     413-7655                 no
# 2736    OK             127        510     403-1128                 no
# 2753    OH             134        415     406-4158                 no
# 1986    WI              70        415     405-9233                 no
# 1052    OR              98        415     378-6772                yes
# 2252    NH             148        408     333-7449                 no
# 3046    MI             110        510     357-5784                 no
# 1621    SC             138        510     370-9533                 no
# 1076    WY              53        415     337-4339                 no
# 2124    KS              43        415     381-9367                 no
# 3174    SC              36        408     359-5091                 no
# ...

# %% [markdown]
# Sorting dataset wrt multiple columns

# %%
df.sort_values(by = ['churn' , 'total eve calls'] , 
               ascending = [True , False] ).head()
# Out:
#      state  account length  area code phone number international plan  \
# 3219    NY             150        415     421-6268                 no
# 58      WI              68        415     403-9733                 no
# 1020    HI             115        415     336-6128                 no
# 1706    MD              54        415     408-6302                 no
# 1071    PA             134        408     408-8650                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# 3219             yes                     35              139.6
# 58                no                      0              148.8
# 1020             yes                     33              145.0
# 1706              no                      0              273.8
# 1071              no                      0              205.3
#
#       total day calls  total day charge  ...    total eve calls  \
# 3219               72             23.73  ...                170
# ...

# %%
df['total day minutes'].mean()
# Out:
# 179.77509750975116

# %%
df[df['churn'] == 1].mean()
# Out:
# account length            102.664596
# area code                 437.817805
# number vmail messages       5.115942
# total day minutes         206.914079
# total day calls           101.335404
# total day charge           35.175921
# total eve minutes         212.410145
# total eve calls           100.561077
# total eve charge           18.054969
# total night minutes       205.231677
# total night calls         100.399586
# total night charge          9.235528
# total intl minutes         10.700000
# total intl calls            4.163561
# total intl charge           2.889545
# customer service calls      2.229814
# churn                       1.000000
# dtype: float64

# %%
df[df['total day minutes'] >= 210]
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 5       AL             118        510     391-8027                yes
# 6       MA             121        510     355-9993                 no
# 9       WV             141        415     330-8173                yes
# 15      NY             161        415     351-7269                 no
# 19      TX              73        415     373-2782                 no
# 26      WY              57        408     357-3817                 no
# 31      NH              75        510     370-3359                 no
# 32      LA             172        408     383-1121                 no
# 33      AZ              12        408     360-1596                 no
# ...

# %% [markdown]
# Average days per min within churn users

# %%
df[df['churn'] == 1]['total day minutes'].mean()
# Out:
# 206.91407867494814

# %% [markdown]
# Max value of customers with no intl plan and churn

# %%
df[(df['churn'] == 0) & (df['international plan'] == 'no')]['total intl minutes'].max()
# Out:
# 18.9

# %% [markdown]
# Displays first 5 rows and columns a to b

# %%
df.loc[0:5, 'area code' : 'voice mail plan']
# Out:
#    area code phone number international plan voice mail plan
# 0        415     382-4657                 no             yes
# 1        415     371-7191                 no             yes
# 2        415     358-1921                 no              no
# 3        408     375-9999                yes              no
# 4        415     330-6626                yes              no
# 5        510     391-8027                yes              no

# %% [markdown]
# Use iloc to slice data with int values

# %%
df.iloc[0:5 , 2:5]
# Out:
#    area code phone number international plan
# 0        415     382-4657                 no
# 1        415     371-7191                 no
# 2        415     358-1921                 no
# 3        408     375-9999                yes
# 4        415     330-6626                yes

# %% [markdown]
# use df[-1:] and df[:1] to display last and first row respectively

# %%
df[:1]
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
#
#    total day charge  ...    total eve calls  total eve charge  \
# 0             45.07  ...                 99             16.78
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
#
#    customer service calls  churn
# 0                       1      0
#
# [1 rows x 21 columns]

# %% [markdown]
# Apply() used to process any functions with in the dataframe

# %%
df.apply(np.max)
# Out:
# state                           WY
# account length                 243
# area code                      510
# phone number              422-9964
# international plan             yes
# voice mail plan                yes
# number vmail messages           51
# total day minutes            350.8
# total day calls                165
# total day charge             59.64
# total eve minutes            363.7
# total eve calls                170
# total eve charge             30.91
# total night minutes            395
# total night calls              175
# total night charge           17.77
# total intl minutes              20
# total intl calls                20
# total intl charge              5.4
# customer service calls           9
# churn                            1
# dtype: object

# %% [markdown]
# Applying lambda function to display states starting with M

# %%
df[df['state'].apply(lambda state: state[0] == 'M')].head()
# Out:
#    state  account length  area code phone number international plan  \
# 6     MA             121        510     355-9993                 no
# 7     MO             147        415     329-9001                yes
# 13    MT              95        510     394-8006                 no
# 27    MT              54        408     418-6412                 no
# 28    MO              20        415     353-2630                 no
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 6              yes                     24              218.2               88
# 7               no                      0              157.0               79
# 13              no                      0              156.6               88
# 27              no                      0              134.3               73
# 28              no                      0              190.0              109
#
#     total day charge  ...    total eve calls  total eve charge  \
# ...

# %% [markdown]
# Replacing values in a column using .replace

# %%
d = {'no' : False , 'yes' : True}
df.replace({'voice mail plan' : d})
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# 5       AL             118        510     391-8027                yes
# 6       MA             121        510     355-9993                 no
# 7       MO             147        415     329-9001                yes
# 8       LA             117        408     335-4719                 no
# 9       WV             141        415     330-8173                yes
# 10      IN              65        415     329-6603                 no
# 11      RI              74        415     344-9403                 no
# ...

# %%
columns_to_show = ['total day minutes', 'total eve minutes','total night minutes']
df.groupby(by = 'international plan')[columns_to_show].describe(percentiles = [])
# Out:
#                    total day minutes                                      \
#                                count        mean        std   min    50%
# international plan
# no                            3010.0  178.893887  54.141286   0.0  179.0
# yes                            323.0  187.986997  56.850451  12.5  188.9
#
#                           total eve minutes                               \
#                       max             count        mean        std   min
# international plan
# no                  350.8            3010.0  200.663090  50.474772   0.0
# yes                 346.8             323.0  203.936842  52.879435  60.8
#
#                                   total night minutes                         \
#                        50%    max               count        mean        std
# international plan
# no                  201.35  361.8              3010.0  201.350831  50.366837
# yes                 202.90  363.7               323.0  196.410217  52.333632
#
#
# ...

# %%
columns_to_show = ['total day minutes', 'total eve minutes','total night minutes']
df.groupby(by = 'international plan')[columns_to_show].agg([np.max,np.min,np.mean,np.std])
# Out:
#                    total day minutes                               \
#                                 amax  amin        mean        std
# international plan
# no                             350.8   0.0  178.893887  54.141286
# yes                            346.8  12.5  187.986997  56.850451
#
#                    total eve minutes                               \
#                                 amax  amin        mean        std
# international plan
# no                             361.8   0.0  200.663090  50.474772
# yes                            363.7  60.8  203.936842  52.879435
#
#                    total night minutes
#                                   amax  amin        mean        std
# international plan
# no                               395.0  23.2  201.350831  50.366837
# yes                              352.5  72.4  196.410217  52.333632

# %% [markdown]
# we can create summary table to see the realtions between two variables . We can also normalize it with attribute normalize = True

# %%
pd.crosstab(df['churn'],
            df['voice mail plan'], 
            margins = True)
# Out:
# voice mail plan    no  yes   All
# churn
# 0                2008  842  2850
# 1                 403   80   483
# All              2411  922  3333

# %%
df.pivot_table(['total day calls', 'total eve calls', 'total night calls'],
               ['area code'], aggfunc='mean')
# Out:
#            total day calls  total eve calls  total night calls
# area code
# 408             100.496420        99.788783          99.039379
# 415             100.576435       100.503927         100.398187
# 510             100.097619        99.671429         100.601190

# %% [markdown]
# Inserting column within a dataframe without using intermediate series

# %%
df['total calls'] = df['total day calls'] + df['total eve calls'] + df['total intl calls'] + df['total night calls']
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge     ...       total eve charge  total night minutes  \
# ...

# %% [markdown]
# Dropping column using drop command. Inplace makes sure that the change is within the specified dataframe. if inplace command is not used then it'll return a new dataframe after performing the operation

# %%
df.drop(['total calls'], 
        axis = 1,
        inplace = True)
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...    total eve calls  total eve charge  \
# ...

# %%
df.drop([1,2]).head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
# 5    AL             118        510     391-8027                yes
# 6    MA             121        510     355-9993                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
# 5              no                      0              223.4               98
# 6             yes                     24              218.2               88
#
#    total day charge  ...    total eve calls  total eve charge  \
# ...

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 
import seaborn as sns
plt.rcParams['image.cmap'] = 'viridis'

# %%
sns.countplot(x = 'international plan', 
              hue = 'churn',
              data = df )

# %%
sns.countplot(x = 'voice mail plan' ,hue = 'international plan', data = df)

# %%
sns.countplot(x = 'customer service calls',
              hue = 'churn', 
              data = df)
